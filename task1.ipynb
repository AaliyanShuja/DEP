# %% [markdown]
# <a href="https://colab.research.google.com/github/AaliyanShuja/DEP/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/content/Daily Household Transactions.csv').head()

# %%
df.head()
# Out:
#                   Date                   Mode        Category  \
# 0  20/09/2018 12:04:08                   Cash  Transportation
# 1  20/09/2018 12:03:15                   Cash            Food
# 2           19/09/2018  Saving Bank account 1    subscription
# 3  17/09/2018 23:41:17  Saving Bank account 1    subscription
# 4  16/09/2018 17:15:08                   Cash       Festivals
#
#                Subcategory                         Note  Amount  \
# 0                    Train         2 Place 5 to Place 0    30.0
# 1                   snacks  Idli medu Vada mix 2 plates    60.0
# 2                  Netflix         1 month subscription   199.0
# 3  Mobile Service Provider            Data booster pack    19.0
# 4             Ganesh Pujan                  Ganesh idol   251.0
#
#   Income/Expense Currency
# 0        Expense      INR
# 1        Expense      INR
# 2        Expense      INR
# 3        Expense      INR
# 4        Expense      INR

# %%
df.dropna(inplace=True)

# %%
df=df.drop_duplicates()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Amount'}>]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            5 non-null      object
#  1   Mode            5 non-null      object
#  2   Category        5 non-null      object
#  3   Subcategory     5 non-null      object
#  4   Note            5 non-null      object
#  5   Amount          5 non-null      float64
#  6   Income/Expense  5 non-null      object
#  7   Currency        5 non-null      object
# dtypes: float64(1), object(7)
# memory usage: 448.0+ bytes

# %%
colors = df['Income/Expense'].map({'Income': 'blue', 'Expense': 'red'})

# %%
plt.figure(figsize=(14,6))
plt.scatter(df['Category'], df['Amount'],c=colors, alpha=0.6)
plt.title('Scatter Plot in between Amount and Category')
plt.xlabel('Category')
plt.ylabel('Amount')
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.scatter(df['Mode'], df['Amount'],c=colors, alpha=0.6)
plt.title('Scatter Plot in between Amount and Mode')
plt.xlabel('Mode')
plt.ylabel('Amount')
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.scatter(df['Date'], df['Amount'],c=colors, alpha=0.6)
plt.title('Scatter Plot in between Amount over time')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(df[['Amount']])
df['Cluster'] = kmeans.predict(df[['Amount']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.figure(figsize=(14, 7))
plt.scatter(df['Category'], df['Amount'], c=df['Cluster'],alpha=0.5)
plt.title('K-means Clustering of in between Amount and Category')
plt.xlabel('Category')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.colorbar(label='Cluster')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.scatter(df['Mode'], df['Amount'], c=df['Cluster'],alpha=0.5)
plt.title('K-means Clustering of in between Amount and Mode')
plt.xlabel('Mode')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.colorbar(label='Cluster')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.scatter(df['Mode'], df['Amount'], c=df['Cluster'],alpha=0.5)
plt.title('K-means Clustering of Amount over Time')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.colorbar(label='Cluster')
plt.show()
